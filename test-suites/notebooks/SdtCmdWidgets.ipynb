# %% [markdown]
# # This is a notebook that is being developed to act a command interface to sdt.
# It uses the interactive widget capability of ipython notebook.

# %% [markdown]
# The `interact` function provides a high-level interface for creating user interface controls to use in exploring code and data interactively.

# %%
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
from IPython.display import clear_output, display, HTML

# %%
def show_args(**kwargs):
    s = '<h3>Arguments:</h3><table>\n'
    for k,v in kwargs.items():
        s += '<tr><td>{0}</td><td>{1}</td></tr>\n'.format(k,v)
    s += '</table>'
    display(HTML(s))

# %%
def send_sdt_cmd(addr,port,sdt_command):
    print "clicked"
    return

# %%
i = interact(show_args,
             port=widgets.BoundedIntTextWidget(value=5000, min=0, max=60000, description='port'),
            addr=u'127.0.0.1',
            sdt_command=u'reset all',
            send_button=widgets.ButtonWidget(description="Send SDT Command")
         )

#send_button.on_click(send_sdt_cmd(addr,port,sdt_command))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/macker/anaconda/lib/python2.7/site-packages/IPython/html/widgets/interaction.pyc in <lambda>(_)
#     218         widget.on_trait_change(call_f, 'value')
#     219
# --> 220     container.on_displayed(lambda _: call_f(None, None, None))
#     221
#     222     return container
#
# /Users/macker/anaconda/lib/python2.7/site-packages/IPython/html/widgets/interaction.pyc in call_f(name, old, new)
#     201         container.kwargs = {}
#     202         for widget in kwargs_widgets:
# --> 203             value = widget.value
#     204             container.kwargs[widget.description] = value
#     205         if co:
#
# AttributeError: 'ButtonWidget' object has no attribute 'value'
# ---------------------------------------------------------------------------
# ...
